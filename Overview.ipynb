# %% [markdown]
# <image src="Untitled design (1).png">

# %% [markdown]
# ## The Idea:
#
# D O N K is a Singleplayer 3D Tank Simulator where the user plays against a Machine Learning Agent as it devlops and trains itself off user movements
#
# ## Deliverables:
#
# The deliverables can be split into Production and Documentation as outlined in the table below.
#
# ### Production
#
# |Deliverable|Description/Evidence|Est. Hours|Due By|Completed (Y/N)|
# |----|----|----|----|----|
# |Additional Modules|Procedural Generation + Machine Learning|15|Sat Wk.8 0000|//|
# |Basic Gameplay|Functional movement, collisions, gameplay with basic AI agent|15|Sat Wk.8 0000|//|
# |Audio & Polish|Bugfixing, OST, Playtesting, ensure FULLY FUNCTIONAL|15|Sat Wk.8 0000|//|
# |Testing & Fixes|Playtesting, Bugfixing, Optimisation|15|Fri Wk.9 0900|//|
# |Total| |60| |//|
#
# ### Documentation
#
# |Deliverable|Description/Evidence|Est. Hours|Due By|Completed (Y/N)|
# |----|----|----|----|----|
# |Project Journal|Pre-documentation, Project Journal to Wk.8|10|Sat Wk.8 0000|//|
# |Documentation Final|Compilation of scripts, documents, journals, etc.|7.5|Fri Wk.9 0900|//|
# |Total| |17.5| |//|
#
# ### Total: 77.5hrs - GENEROUSLY, 55hrs - MINIMUM
#
# ## Week-by-Week Plan:
#
# |Week|Hours Planned|Specific Goals|Evidence|Actual Hours|Comment|
# |---|---|---|---|---|---|
# |6|17.5|Basic Gameplay (as above) + Project Journal|GitHub Commits + Project Journal + Unity Project File|//|- |
# |7|17.5|Additional Modules (as above) + Project Journal|GitHub Commits + Project Journal + Unity Project File|//|- |
# |8|17.5|Audio & Polish (as above) + Project Journal|GitHub Commits + Project Journal + Unity Project File|//|- |
# |9|25|Testing & Fixes (as above) + Documentation Final (as above) + Project Journal|GitHub Commits + Project Journal + Unity Project File + Built Game + Devlog + Itch.IO Link|//|- |
#
# ## Risk Assessment:
#
# |Potential Problem|Impact|Prevention|
# |---|---|---|
# |Getting carried away on making the ML work|Time waste on one thing|"Point of No Return" after which ML will be abandoned. PNR is set at: End of Week 7|
# |Overassumption of work being complete in class and outside of school|Lack of productivity|Buddy system to positively encourage work being done in class|
#
# ## Teacher Check Ins:
#
# |Checkpoint|Date|Teacher Comment|Signed (Y/N)|
# |---|---|---|---|
# |Initial Plan Approved|10/11/25|Guard Rails Around Scope;ML - User supervised/unsupervised;Use Test Cases;Limited - but prove it works|Y|
# |Week 7 Review|- |- |//|
# |Final Review|- |- |//|
#
# ## PAR - Reflection:
#
# ### What went well?
#
# ### What didn't go to plan?
#
# ### What would you do differently next time?
