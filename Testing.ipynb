# %% [markdown]
# <image src="Untitled design (1).png">

# %% [markdown]
# # Machine Learning - Is It Even Possible?
#
# It would be a real bummer to come up with all of these ideas and all these systems to be completely ruined by the fact this isn't possible.
#
# After consulting with ChatGPT
